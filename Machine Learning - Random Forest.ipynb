# %%
import psycopg2

# %%
# Initial imports
import pandas as pd
import sqlite3 as sql
from pathlib import Path
from sqlalchemy import create_engine
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import numpy as np

# %matplotlib inline

# %%
con = psycopg2.connect(
database="Sleep_Project",
user="postgres",
password="postgres",
host="localhost",
port= '5432'
)

# %%
cursor_obj = con.cursor()
cursor_obj.execute("SELECT * FROM sleep_project")

# %%
sleep_df= pd.DataFrame(cursor_obj.fetchall(),columns = ["Sleep duration","Caffeine consumption","Alcohol consumption","Exercise frequency","Female","Male","Late Bedtime","Normal Bedtime","Really Late Bedtime","Non-Smoker","Smoker","Early Wakeup","Late Wakeup","Normal Wakeup","Very Early Wakeup","Efficient"])

# %%
sleep_df.head()
# Out:
#   Sleep duration  Caffeine consumption  Alcohol consumption  \
# 0            7.5                    50                    0
# 1            5.5                     0                    0
# 2            7.0                     0                    5
# 3            8.0                     0                    0
# 4            9.0                    75                    0
#
#    Exercise frequency  Female  Male  Late Bedtime  Normal Bedtime  \
# 0                   1       1     0             0               0
# 1                   0       0     1             0               0
# 2                   2       1     0             0               0
# 3                   3       0     1             0               0
# 4                   2       1     0             0               1
#
#    Really Late Bedtime  Non-Smoker  Smoker  Early Wakeup  Late Wakeup  \
# 0                    1           1       0             1            0
# ...

# %%
#zip_database_path = Path("/Users/zepedro15/Desktop/Final Project/Final_sleep_Project")
#engine = create_engine(f"sqlite:///{zip_database_path}")
#conn = engine.connect()

# %%
# Loading data
#sleep_df = pd.read_csv("sleep_df_cleandrop.csv")

#sleep_df.head()

# %%
# Define features set
X = sleep_df.copy()
X.drop("Efficient", axis=1, inplace=True)
X.head()
# Out:
#   Sleep duration  Caffeine consumption  Alcohol consumption  \
# 0            7.5                    50                    0
# 1            5.5                     0                    0
# 2            7.0                     0                    5
# 3            8.0                     0                    0
# 4            9.0                    75                    0
#
#    Exercise frequency  Female  Male  Late Bedtime  Normal Bedtime  \
# 0                   1       1     0             0               0
# 1                   0       0     1             0               0
# 2                   2       1     0             0               0
# 3                   3       0     1             0               0
# 4                   2       1     0             0               1
#
#    Really Late Bedtime  Non-Smoker  Smoker  Early Wakeup  Late Wakeup  \
# 0                    1           1       0             1            0
# ...

# %%
# Define target vector
y = sleep_df["Efficient"].ravel()
y[:5]
# Out:
# array([1, 0, 1, 0, 1])

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=8)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
 # Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           20           12
# Actual 1            5           62
# Accuracy Score : 0.8282828282828283
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.62      0.70        32
#            1       0.84      0.93      0.88        67
#
#     accuracy                           0.83        99
#    macro avg       0.82      0.78      0.79        99
# weighted avg       0.83      0.83      0.82        99

# %%
answers = []

while True:
    
    z = int(input("How many hours do you plan to sleep tonight (1-10) : "))
    answers.append(z)

    a = int(input("Enter how many mg of caffeine you have had today. 1 cup of coffee = 95mg : "))
    answers.append(a)
    
    b = int(input("Enter how many drinks of alcohol you've had today. : "))
    answers.append(b)
    
    c = int(input("Enter how many times a week you excercise. : "))
    answers.append(c)
    
    d = int(input("Are you Male? Enter 1 for Yes or 0 for No. : "))
    answers.append(d)
    
    e = int(input("Are you Female? Enter 1 for Yes or 0 for No. : "))
    answers.append(e)
    
    f = int(input("Will you be going to sleep between the hours of 11pm - 1am? Enter 1 for Yes or 0 for No. : "))
    answers.append(f)
    
    g = int(input("Will you be going to sleep between the hours of 9pm - 11pm? Enter 1 for Yes or 0 for No. : "))
    answers.append(g)
    
    h = int(input("Will you be going to sleep between the hours of 1am - 3am? Enter 1 for Yes or 0 for No. : "))
    answers.append(h)
    
    i = int(input("Are you a Non-Smoker? Enter 1 for Yes or 0 for No. : "))
    answers.append(i)
    
    j = int(input("Are you a Smoker? Enter 1 for Yes or 0 for No. : "))
    answers.append(j)
    
    k = int(input("Will you be waking up between the hours of 5am - 8am? Enter 1 for Yes or 0 for No. : "))
    answers.append(k)
    
    l = int(input("Will you be waking up between the hours of 11am - 1pm? Enter 1 for Yes or 0 for No. : "))
    answers.append(l)
    
    m = int(input("Will you be waking up between the hours of 8am - 11am? Enter 1 for Yes or 0 for No. : "))
    answers.append(m)
    
    n = int(input("Will you be waking up between the hours of 3am - 5am? Enter 1 for Yes or 0 for No. : "))
    answers.append(n)

    break
 
print(answers)
# Out:
# How many hours do you plan to sleep tonight (1-10) : 7
# Enter how many mg of caffeine you have had today. 1 cup of coffee = 95mg : 95
# Enter how many drinks of alcohol you've had today. : 2
# Enter how many times a week you excercise. : 4
# Are you Male? Enter 1 for Yes or 0 for No. : 1
# Are you Female? Enter 1 for Yes or 0 for No. : 0
# Will you be going to sleep between the hours of 11pm - 1am? Enter 1 for Yes or 0 for No. : 1
# Will you be going to sleep between the hours of 9pm - 11pm? Enter 1 for Yes or 0 for No. : 0
# Will you be going to sleep between the hours of 1am - 3am? Enter 1 for Yes or 0 for No. : 0
# Are you a Non-Smoker? Enter 1 for Yes or 0 for No. : 1
# Are you a Smoker? Enter 1 for Yes or 0 for No. : 0
# Will you be waking up between the hours of 5am - 8am? Enter 1 for Yes or 0 for No. : 1
# Will you be waking up between the hours of 11am - 1pm? Enter 1 for Yes or 0 for No. : 0
# ...

# %%
import numpy as np
arr = np.array(answers)

arr1 = arr.reshape(1, -1)

print(arr1)
# Out:
# [[ 7 95  2  4  1  0  1  0  0  1  0  1  0  0  0]]

# %%
#features = np.array([[25, 5, 0, 0, 1, 0, 0, 1, 1, 0, 0, 1, 0, 0]])
features = arr1
# using inputs to predict the output
prediction = rf_model.predict(features)
print("Prediction: {}".format(prediction))
# Out:
# Prediction: [1]
